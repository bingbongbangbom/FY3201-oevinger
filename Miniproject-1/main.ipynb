# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.collections import PatchCollection
from matplotlib.colors import ListedColormap
import pandas as pd

# %%
import pandas as pd

# -----  replace with the real path to your file  -----
path_to_file = "data/Land_and_Ocean_complete.txt"

# Read the file:
df = pd.read_csv(
    path_to_file,
    comment="%",                # ignore all lines that start with “%”
    delim_whitespace=True,      # split on any amount of space / tab
    header=None,                # the file has no header line
    names=[
        "year", "month",
        "monthly_anom", "monthly_unc",
        "annual_anom", "annual_unc",
        "5yr_anom", "5yr_unc",
        "10yr_anom", "10yr_unc",
        "20yr_anom", "20yr_unc",
    ],
    na_values="NaN",            # turn the literal string “NaN” into np.nan
    dtype={"year": int, "month": int}
)

# Quick look at the first rows:
print(df.head())
# Out:
#    year  month  monthly_anom  monthly_unc  annual_anom  annual_unc  5yr_anom  \
# 0  1850      1        -0.753        0.365          NaN         NaN       NaN
# 1  1850      2        -0.202        0.416          NaN         NaN       NaN
# 2  1850      3        -0.367        0.373          NaN         NaN       NaN
# 3  1850      4        -0.596        0.324          NaN         NaN       NaN
# 4  1850      5        -0.619        0.267          NaN         NaN       NaN
#
#    5yr_unc  10yr_anom  10yr_unc  20yr_anom  20yr_unc
# 0      NaN        NaN       NaN        NaN       NaN
# 1      NaN        NaN       NaN        NaN       NaN
# 2      NaN        NaN       NaN        NaN       NaN
# 3      NaN        NaN       NaN        NaN       NaN
# 4      NaN        NaN       NaN        NaN       NaN
# ...

# %%
# Test - Ole
variabel = 1
